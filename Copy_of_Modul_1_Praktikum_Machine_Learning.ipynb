# %% [markdown]
# <a href="https://colab.research.google.com/github/cassiejc/24-8-2023/blob/master/Copy_of_Modul_1_Praktikum_Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data Analysis with NumPy, Matplotlib and Pandas**

# %% [markdown]
# # **Tujuan**
# * Praktikan mampu memahami penggunaan library NumPy, Pandas, dan Matplotlib untuk melakukan pengolahan data
# *  Praktikan mampu melakukan proses cleaning data sebelum melakukan analisis data
# *   Praktikan mampu memahami penggunaan library NumPy, Pandas, dan Matplotlib untuk melakukan visualisasi data
# * Praktikan mampu membuat berbagai macam chart

# %% [markdown]
# # **Dataset**
#
# Pada modul ini, dataset yang digunakan adalah dataset mengenai kemiskinan nasional. Dataset tersebut dapat di-download melalui link berikut
#
# [Data Kemiskinan 2018-2022.xlsx](https://docs.google.com/spreadsheets/d/16GE0UWS_W0EuS85QLIArm-PzFnVmxY37/edit?usp=sharing&ouid=115607745042758487879&rtpof=true&sd=true)
#
# File `Data Kemiskinan 2018-2022.xlsx` yang sudah di-download dapat di-upload langsung ke workspace Google Colab atau bisa di-upload ke google drive

# %% [markdown]
# # **Import library**
#
# Terdapat 3 library yang akan digunakan untuk melakukan analisis data, yaitu
#
# - **NumPy**: Numerical computing
# - **Pandas**: Data manipulation
# - **Matplotlib**: Data visualization

# %%
#Import library
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # **Membaca Data**
#
# Selanjutnya, dataset dapat dibaca menggunakan `pd.read_<file type>()` yang terdapat di Pandas. Sebagai contoh, untuk membaca file `excel`, kita dapat menggunakan `pd.read_excel("nama file.xlsx")`. Apabila `sheet_name` tidak diisi, secara default sheet yang terbaca adalah sheet pertama

# %%
#Import dataset
data = pd.read_excel("Data Kemiskinan 2018-2022.xlsx")
data
# Out:
#                    Tahun                            Indikator  \
# 0    2018-01-01 00:00:00  Persentase Penduduk Miskin Provinsi
# 1    2018-01-01 00:00:00  Persentase Penduduk Miskin Provinsi
# 2    2018-01-01 00:00:00  Persentase Penduduk Miskin Provinsi
# 3    2018-01-01 00:00:00  Persentase Penduduk Miskin Provinsi
# 4    2018-01-01 00:00:00  Persentase Penduduk Miskin Provinsi
# ..                   ...                                  ...
# 878  2022-01-01 00:00:00                  Gini Ratio Provinsi
# 879  2022-01-01 00:00:00                  Gini Ratio Provinsi
# 880  2022-01-01 00:00:00                  Gini Ratio Provinsi
# 881  2022-01-01 00:00:00                  Gini Ratio Provinsi
# 882  2022-01-01 00:00:00                  Gini Ratio Provinsi
#
#                       Provinsi Unit      Nilai
# 0                        PAPUA    %  27.740000
# 1                  PAPUA BARAT    %  23.010000
# 2          NUSA TENGGARA TIMUR    %  21.350000
# 3                       MALUKU    %  18.120001
# 4                    GORONTALO    %  16.809999
# ..                         ...  ...        ...
# 878                     MALUKU    %   0.301000
# 879             SUMATERA BARAT    %   0.300000
# 880               MALUKU UTARA    %   0.279000
# 881           KALIMANTAN UTARA    %   0.272000
# 882  KEPULAUAN BANGKA BELITUNG    %   0.236000
#
# [883 rows x 5 columns]

# %% [markdown]
# # **Melihat Data**
#
# Berikut adalah beberapa cara dasar untuk melihat data di Pandas:
# - `head(n)` : Berfungsi untuk melihat data sebanyak n pada baris awal (jika tidak diisi, secara default n = 5)
# - `tail(n)`: Berfungsi untuk melihat data sebanyak n pada baris akhir (jika tidak diisi, secara default n = 5)
# - `columns` : Berfungsi untuk melihat nama-nama kolom pada dataset
# - `shape` : Melihat jumlah baris dan kolom
# - `info()` : Menampilkan nomor index beserta tipe datanya

# %%
#Menggunakan head
data.head()
# Out:
#                  Tahun                            Indikator  \
# 0  2018-01-01 00:00:00  Persentase Penduduk Miskin Provinsi
# 1  2018-01-01 00:00:00  Persentase Penduduk Miskin Provinsi
# 2  2018-01-01 00:00:00  Persentase Penduduk Miskin Provinsi
# 3  2018-01-01 00:00:00  Persentase Penduduk Miskin Provinsi
# 4  2018-01-01 00:00:00  Persentase Penduduk Miskin Provinsi
#
#               Provinsi Unit      Nilai
# 0                PAPUA    %  27.740000
# 1          PAPUA BARAT    %  23.010000
# 2  NUSA TENGGARA TIMUR    %  21.350000
# 3               MALUKU    %  18.120001
# 4            GORONTALO    %  16.809999

# %%
#Menggunakan tail
data.tail(3)
# Out:
#                    Tahun            Indikator                   Provinsi Unit  \
# 880  2022-01-01 00:00:00  Gini Ratio Provinsi               MALUKU UTARA    %
# 881  2022-01-01 00:00:00  Gini Ratio Provinsi           KALIMANTAN UTARA    %
# 882  2022-01-01 00:00:00  Gini Ratio Provinsi  KEPULAUAN BANGKA BELITUNG    %
#
#      Nilai
# 880  0.279
# 881  0.272
# 882  0.236

# %%
#Menggunakan shape
data.shape
# Out:
# (883, 5)

# %%
#Menggunakan info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 883 entries, 0 to 882
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Tahun      883 non-null    object
#  1   Indikator  883 non-null    object
#  2   Provinsi   877 non-null    object
#  3   Unit       877 non-null    object
#  4   Nilai      877 non-null    float64
# dtypes: float64(1), object(4)
# memory usage: 34.6+ KB

# %% [markdown]
# #**Data Cleaning**
#
# Pembersihan data (data cleaning) adalah suatu proses yang melibatkan identifikasi dan koreksi, atau penghapusan data yang tidak benar dari sebuah dataset. Data yang perlu dibersihkan dapat meliputi:
# 1. Data yang tidak lengkap atau mengandung missing value
# 2. Data dengan format tipe data yang tidak sesuai
# 3. Data yang duplikat
#
# Proses ini dilakukan untuk memastikan bahwa data dalam dataset bersih, akurat, dan sesuai sehingga dapat digunakan untuk analisis lebih lanjut

# %% [markdown]
# ## **Menghilangkan baris yang memiliki missing value**
#
# Untuk menghilangkan baris yang memiliki missing value, kita bisa menggunakan  `dropna()`. Untuk mengetahui apakah data frame memiliki missing value, kita dapat menggunakan `isna()` seperti berikut

# %%
data[data.Provinsi.isna()]
# Out:
#                    Tahun                                Indikator Provinsi  \
# 18   2018-01-01 00:00:00      Persentase Penduduk Miskin Provinsi      NaN
# 19   2018-01-01 00:00:00      Persentase Penduduk Miskin Provinsi      NaN
# 167  2018-01-01 00:00:00                      Gini Ratio Provinsi      NaN
# 621  2021-01-01 00:00:00  Indeks Kedalaman Kemiskinan P1 Provinsi      NaN
# 629  2021-01-01 00:00:00  Indeks Kedalaman Kemiskinan P1 Provinsi      NaN
# 630  2021-01-01 00:00:00  Indeks Kedalaman Kemiskinan P1 Provinsi      NaN
#
#     Unit  Nilai
# 18   NaN    NaN
# 19   NaN    NaN
# 167  NaN    NaN
# 621  NaN    NaN
# 629  NaN    NaN
# 630  NaN    NaN

# %% [markdown]
# Untuk menghilangkan beberapa baris tersebut kita akan menggunakan `dropna()`. Secara default, `dropna()` akan memberikan sebuah data frame baru dan tidak akan merubah data frame awal. Jika ingin mengubah data frame awal, kita harus menggunakan argumen `inplace = True`

# %%
data.dropna(inplace=True)

# %% [markdown]
# Setelah menjalankan kode di atas, maka missing value pada dataframe awal sudah dihilangkan

# %%
data[data.Provinsi.isna()]
# Out:
# Empty DataFrame
# Columns: [Tahun, Indikator, Provinsi, Unit, Nilai]
# Index: []

# %% [markdown]
# ## **Memperbaiki data dengan tipe data yang tidak sesuai**
#
# Dengan menggunakan `data.info()` dapat dilihat bahwa kolom Tahun memiliki tipe data object, yang mana seharusnya tipe data kolom Tahun adalah `datetime` untuk memudahkan kita melakukan analisis dan visualisasi data. Oleh karena itu, kita harus mengubah tipe data pada kolom Tahun menjadi tipe data datetime dengan memanfaatkan `to_datetime()` pada pandas

# %%
data.Tahun = pd.to_datetime(data.Tahun)

# %% [markdown]
# Setelah menjalankan kode di atas, maka tipe data kolom Tahun memiliki tipe data datetime

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 877 entries, 0 to 882
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Tahun      877 non-null    datetime64[ns]
#  1   Indikator  877 non-null    object
#  2   Provinsi   877 non-null    object
#  3   Unit       877 non-null    object
#  4   Nilai      877 non-null    float64
# dtypes: datetime64[ns](1), float64(1), object(3)
# memory usage: 41.1+ KB

# %% [markdown]
# ##**Menghilangkan data duplikat**
#
# Untuk mengecek apakah ada data duplikat pada dataframe, kita bisa menggunakan  `duplicated()` yang akan mengembalikan nilai True untuk setiap baris yang memiliki duplikat dan False untuk yang tidak. Sehingga, kita bisa melihat apakah terdapat baris yang memiliki duplikat dengan kode berikut

# %%
data[data.duplicated()==True]
# Out:
#          Tahun                                Indikator         Provinsi  \
# 80  2018-01-01  Indeks Kedalaman Kemiskinan P1 Provinsi  SULAWESI TENGAH
# 172 2018-01-01                      Gini Ratio Provinsi          LAMPUNG
#
#        Unit  Nilai
# 80   indeks   2.64
# 172       %   0.33

# %% [markdown]
# Dapat dilihat bahwa terdapat 2 baris yang memiliki duplikat. Kita dapat menghilangkan data duplikat tersebut dengan `drop_duplicates()`. Jangan lupa menambahkan argumen `inplace = True` agar data duplikat di data frame awal juga hilang

# %%
data.drop_duplicates(inplace = True)

# %% [markdown]
# Setelah menjalankan kode di atas, data duplikat sudah dihilangkan

# %%
data[data.duplicated()==True]
# Out:
# Empty DataFrame
# Columns: [Tahun, Indikator, Provinsi, Unit, Nilai]
# Index: []

# %% [markdown]
# #**Memfilter Data**
#
# Data bisa di-filter atau diseleksi berdasarkan kondisi yang diinginkan. Contohnya jika kita ingin melihat kondisi sebuah provinsi, maka kita bisa melakukan filer untuk menampilkan data mengenai provinsi itu saja.

# %%
#Contoh memfilter data
kondisi = data.Provinsi == "PAPUA"
data[kondisi]
# Out:
#          Tahun                                Indikator Provinsi    Unit  \
# 0   2018-01-01      Persentase Penduduk Miskin Provinsi    PAPUA       %
# 39  2018-01-01             Pertumbuhan Ekonomi Provinsi    PAPUA       %
# 72  2018-01-01  Indeks Kedalaman Kemiskinan P1 Provinsi    PAPUA  indeks
# 109 2018-01-01  Indeks Keparahan Kemiskinan P2 Provinsi    PAPUA  indeks
# 153 2018-01-01                      Gini Ratio Provinsi    PAPUA       %
# 180 2019-01-01      Persentase Penduduk Miskin Provinsi    PAPUA       %
# 249 2019-01-01             Pertumbuhan Ekonomi Provinsi    PAPUA       %
# 250 2019-01-01  Indeks Kedalaman Kemiskinan P1 Provinsi    PAPUA  indeks
# 285 2019-01-01  Indeks Keparahan Kemiskinan P2 Provinsi    PAPUA  indeks
# 325 2019-01-01                      Gini Ratio Provinsi    PAPUA       %
# 355 2020-01-01      Persentase Penduduk Miskin Provinsi    PAPUA       %
# 390 2020-01-01  Indeks Kedalaman Kemiskinan P1 Provinsi    PAPUA  indeks
# 427 2020-01-01             Pertumbuhan Ekonomi Provinsi    PAPUA       %
# 460 2020-01-01  Indeks Keparahan Kemiskinan P2 Provinsi    PAPUA  indeks
# 499 2020-01-01                      Gini Ratio Provinsi    PAPUA       %
# 530 2021-01-01      Persentase Penduduk Miskin Provinsi    PAPUA       %
# 566 2021-01-01             Pertumbuhan Ekonomi Provinsi    PAPUA       %
# 600 2021-01-01  Indeks Kedalaman Kemiskinan P1 Provinsi    PAPUA  indeks
# 639 2021-01-01  Indeks Keparahan Kemiskinan P2 Provinsi    PAPUA  indeks
# 676 2021-01-01                      Gini Ratio Provinsi    PAPUA       %
# 708 2022-01-01      Persentase Penduduk Miskin Provinsi    PAPUA       %
# 745 2022-01-01             Pertumbuhan Ekonomi Provinsi    PAPUA       %
# 807 2022-01-01  Indeks Kedalaman Kemiskinan P1 Provinsi    PAPUA  indeks
# 813 2022-01-01  Indeks Keparahan Kemiskinan P2 Provinsi    PAPUA  indeks
# 852 2022-01-01                      Gini Ratio Provinsi    PAPUA       %
#
#          Nilai
# 0    27.740000
# 39    7.320000
# 72    6.730000
# 109   2.280000
# 153   0.384000
# 180  27.530001
# 249 -15.740000
# 250   7.170000
# 285   2.600000
# 325   0.394000
# 355  26.639999
# 390   6.160000
# 427   2.390000
# 460   2.080000
# 499   0.392000
# 530  26.860001
# 566  15.160000
# 600   5.600000
# 639   1.690000
# 676   0.397000
# 708  26.559999
# 745   8.970000
# 807   0.890000
# 813   2.100000
# 852   0.406000

# %% [markdown]
# Memfilter data dengan lebih dari satu kondisi, dapat dilakukan dengan logika AND dan OR:
# - Simbol `&` untuk `dan`
# - Simbol `|` untuk `atau`

# %%
#Menggunakan & untuk melihat data mengenai persenatse penduduk miskin di provinsi Aceh
kondisi1 = data.Provinsi == "ACEH"
kondisi2 = data.Indikator == "Persentase Penduduk Miskin Provinsi"
data[kondisi1 & kondisi2]
# Out:
#          Tahun                            Indikator Provinsi Unit  Nilai
# 5   2018-01-01  Persentase Penduduk Miskin Provinsi     ACEH    %  15.97
# 185 2019-01-01  Persentase Penduduk Miskin Provinsi     ACEH    %  15.32
# 361 2020-01-01  Persentase Penduduk Miskin Provinsi     ACEH    %  14.99
# 536 2021-01-01  Persentase Penduduk Miskin Provinsi     ACEH    %  15.33
# 713 2022-01-01  Persentase Penduduk Miskin Provinsi     ACEH    %  14.64

# %% [markdown]
#  `isin` dapat digunakan untuk memilih data yang nilainya terdapat dalam sebuah list.

# %%
#Menggunakan & dan isin untuk menampilkan data pertumbuhan ekonomi provinsi di Jawa Timur, Jawa Barat, dan Jawa Tengah
data[(data.Provinsi.isin(["JAWA TIMUR", "JAWA BARAT", "JAWA TENGAH"])) & (data.Indikator == "Pertumbuhan Ekonomi Provinsi")]
# Out:
#          Tahun                     Indikator     Provinsi Unit  Nilai
# 52  2018-01-01  Pertumbuhan Ekonomi Provinsi   JAWA BARAT    %   5.65
# 54  2018-01-01  Pertumbuhan Ekonomi Provinsi   JAWA TIMUR    %   5.47
# 56  2018-01-01  Pertumbuhan Ekonomi Provinsi  JAWA TENGAH    %   5.30
# 228 2019-01-01  Pertumbuhan Ekonomi Provinsi   JAWA TIMUR    %   5.53
# 230 2019-01-01  Pertumbuhan Ekonomi Provinsi  JAWA TENGAH    %   5.36
# 237 2019-01-01  Pertumbuhan Ekonomi Provinsi   JAWA BARAT    %   5.02
# 450 2020-01-01  Pertumbuhan Ekonomi Provinsi   JAWA TIMUR    %  -2.33
# 453 2020-01-01  Pertumbuhan Ekonomi Provinsi   JAWA BARAT    %  -2.52
# 454 2020-01-01  Pertumbuhan Ekonomi Provinsi  JAWA TENGAH    %  -2.65
# 576 2021-01-01  Pertumbuhan Ekonomi Provinsi   JAWA BARAT    %   3.74
# 582 2021-01-01  Pertumbuhan Ekonomi Provinsi   JAWA TIMUR    %   3.56
# 586 2021-01-01  Pertumbuhan Ekonomi Provinsi  JAWA TENGAH    %   3.33
# 749 2022-01-01  Pertumbuhan Ekonomi Provinsi   JAWA BARAT    %   5.45
# 751 2022-01-01  Pertumbuhan Ekonomi Provinsi   JAWA TIMUR    %   5.34
# 754 2022-01-01  Pertumbuhan Ekonomi Provinsi  JAWA TENGAH    %   5.31

# %% [markdown]
# #**Sorting dan Grouping Data**
#
# Sorting data dapat dilakukan dengan menggunakan `sort_values()` pada Pandas. Secara default, data akan diurutkan dari nilai yang rendah ke tinggi (secara ascending). Akan tetapi, data dapat diurutkan dari tinggi ke rendah (descending) dengan cara menambahkan argumen `ascending = False`

# %% [markdown]
# ###Sorting

# %%
#Sort value berdasarkan data yang memenuhi kondisi
kondisi3 = data.Tahun.dt.year == 2021 #dt.year digunakan untuk mendapatkan tahun pada tipe data datetime
kondisi4 = data.Indikator == "Pertumbuhan Ekonomi Provinsi"
data[kondisi3 & kondisi4].sort_values(by="Nilai")
# Out:
#          Tahun                     Indikator                   Provinsi Unit  \
# 599 2021-01-01  Pertumbuhan Ekonomi Provinsi                       BALI    %
# 598 2021-01-01  Pertumbuhan Ekonomi Provinsi                PAPUA BARAT    %
# 597 2021-01-01  Pertumbuhan Ekonomi Provinsi        NUSA TENGGARA BARAT    %
# 596 2021-01-01  Pertumbuhan Ekonomi Provinsi                  GORONTALO    %
# 595 2021-01-01  Pertumbuhan Ekonomi Provinsi        NUSA TENGGARA TIMUR    %
# 594 2021-01-01  Pertumbuhan Ekonomi Provinsi           KALIMANTAN TIMUR    %
# 593 2021-01-01  Pertumbuhan Ekonomi Provinsi             SULAWESI BARAT    %
# 592 2021-01-01  Pertumbuhan Ekonomi Provinsi             SUMATERA UTARA    %
# 591 2021-01-01  Pertumbuhan Ekonomi Provinsi                    LAMPUNG    %
# 590 2021-01-01  Pertumbuhan Ekonomi Provinsi                       ACEH    %
# 589 2021-01-01  Pertumbuhan Ekonomi Provinsi                     MALUKU    %
# 588 2021-01-01  Pertumbuhan Ekonomi Provinsi                   BENGKULU    %
# 587 2021-01-01  Pertumbuhan Ekonomi Provinsi             SUMATERA BARAT    %
# 586 2021-01-01  Pertumbuhan Ekonomi Provinsi                JAWA TENGAH    %
# 585 2021-01-01  Pertumbuhan Ekonomi Provinsi                       RIAU    %
# 584 2021-01-01  Pertumbuhan Ekonomi Provinsi             KEPULAUAN RIAU    %
# 583 2021-01-01  Pertumbuhan Ekonomi Provinsi         KALIMANTAN SELATAN    %
# 581 2021-01-01  Pertumbuhan Ekonomi Provinsi                DKI JAKARTA    %
# 582 2021-01-01  Pertumbuhan Ekonomi Provinsi                 JAWA TIMUR    %
# 580 2021-01-01  Pertumbuhan Ekonomi Provinsi           SUMATERA SELATAN    %
# 579 2021-01-01  Pertumbuhan Ekonomi Provinsi          KALIMANTAN TENGAH    %
# 578 2021-01-01  Pertumbuhan Ekonomi Provinsi                      JAMBI    %
# 577 2021-01-01  Pertumbuhan Ekonomi Provinsi                  INDONESIA    %
# 576 2021-01-01  Pertumbuhan Ekonomi Provinsi                 JAWA BARAT    %
# 575 2021-01-01  Pertumbuhan Ekonomi Provinsi           KALIMANTAN UTARA    %
# 574 2021-01-01  Pertumbuhan Ekonomi Provinsi          SULAWESI TENGGARA    %
# 573 2021-01-01  Pertumbuhan Ekonomi Provinsi             SULAWESI UTARA    %
# 572 2021-01-01  Pertumbuhan Ekonomi Provinsi                     BANTEN    %
# 571 2021-01-01  Pertumbuhan Ekonomi Provinsi           SULAWESI SELATAN    %
# 570 2021-01-01  Pertumbuhan Ekonomi Provinsi           KALIMANTAN BARAT    %
# 569 2021-01-01  Pertumbuhan Ekonomi Provinsi  KEPULAUAN BANGKA BELITUNG    %
# 568 2021-01-01  Pertumbuhan Ekonomi Provinsi              DI YOGYAKARTA    %
# 567 2021-01-01  Pertumbuhan Ekonomi Provinsi            SULAWESI TENGAH    %
# 566 2021-01-01  Pertumbuhan Ekonomi Provinsi                      PAPUA    %
# 565 2021-01-01  Pertumbuhan Ekonomi Provinsi               MALUKU UTARA    %
#
#          Nilai
# 599  -2.460000
# 598  -0.510000
# 597   2.300000
# 596   2.410000
# 595   2.520000
# 594   2.550000
# 593   2.570000
# 592   2.610000
# 591   2.770000
# 590   2.790000
# 589   3.050000
# 588   3.270000
# 587   3.290000
# 586   3.330000
# 585   3.360000
# 584   3.430000
# 583   3.480000
# 581   3.560000
# 582   3.560000
# 580   3.580000
# 579   3.590000
# 578   3.690000
# 577   3.700000
# 576   3.740000
# 575   3.980000
# 574   4.100000
# 573   4.160000
# 572   4.490000
# 571   4.640000
# 570   4.800000
# 569   5.050000
# 568   5.580000
# 567  11.700000
# 566  15.160000
# 565  16.790001

# %%
#Sort values tapi descending
data[kondisi3 & kondisi4].sort_values(by="Nilai", ascending = False)
# Out:
#          Tahun                     Indikator                   Provinsi Unit  \
# 565 2021-01-01  Pertumbuhan Ekonomi Provinsi               MALUKU UTARA    %
# 566 2021-01-01  Pertumbuhan Ekonomi Provinsi                      PAPUA    %
# 567 2021-01-01  Pertumbuhan Ekonomi Provinsi            SULAWESI TENGAH    %
# 568 2021-01-01  Pertumbuhan Ekonomi Provinsi              DI YOGYAKARTA    %
# 569 2021-01-01  Pertumbuhan Ekonomi Provinsi  KEPULAUAN BANGKA BELITUNG    %
# 570 2021-01-01  Pertumbuhan Ekonomi Provinsi           KALIMANTAN BARAT    %
# 571 2021-01-01  Pertumbuhan Ekonomi Provinsi           SULAWESI SELATAN    %
# 572 2021-01-01  Pertumbuhan Ekonomi Provinsi                     BANTEN    %
# 573 2021-01-01  Pertumbuhan Ekonomi Provinsi             SULAWESI UTARA    %
# 574 2021-01-01  Pertumbuhan Ekonomi Provinsi          SULAWESI TENGGARA    %
# 575 2021-01-01  Pertumbuhan Ekonomi Provinsi           KALIMANTAN UTARA    %
# 576 2021-01-01  Pertumbuhan Ekonomi Provinsi                 JAWA BARAT    %
# 577 2021-01-01  Pertumbuhan Ekonomi Provinsi                  INDONESIA    %
# 578 2021-01-01  Pertumbuhan Ekonomi Provinsi                      JAMBI    %
# 579 2021-01-01  Pertumbuhan Ekonomi Provinsi          KALIMANTAN TENGAH    %
# 580 2021-01-01  Pertumbuhan Ekonomi Provinsi           SUMATERA SELATAN    %
# 581 2021-01-01  Pertumbuhan Ekonomi Provinsi                DKI JAKARTA    %
# 582 2021-01-01  Pertumbuhan Ekonomi Provinsi                 JAWA TIMUR    %
# 583 2021-01-01  Pertumbuhan Ekonomi Provinsi         KALIMANTAN SELATAN    %
# 584 2021-01-01  Pertumbuhan Ekonomi Provinsi             KEPULAUAN RIAU    %
# 585 2021-01-01  Pertumbuhan Ekonomi Provinsi                       RIAU    %
# 586 2021-01-01  Pertumbuhan Ekonomi Provinsi                JAWA TENGAH    %
# 587 2021-01-01  Pertumbuhan Ekonomi Provinsi             SUMATERA BARAT    %
# 588 2021-01-01  Pertumbuhan Ekonomi Provinsi                   BENGKULU    %
# 589 2021-01-01  Pertumbuhan Ekonomi Provinsi                     MALUKU    %
# 590 2021-01-01  Pertumbuhan Ekonomi Provinsi                       ACEH    %
# 591 2021-01-01  Pertumbuhan Ekonomi Provinsi                    LAMPUNG    %
# 592 2021-01-01  Pertumbuhan Ekonomi Provinsi             SUMATERA UTARA    %
# 593 2021-01-01  Pertumbuhan Ekonomi Provinsi             SULAWESI BARAT    %
# 594 2021-01-01  Pertumbuhan Ekonomi Provinsi           KALIMANTAN TIMUR    %
# 595 2021-01-01  Pertumbuhan Ekonomi Provinsi        NUSA TENGGARA TIMUR    %
# 596 2021-01-01  Pertumbuhan Ekonomi Provinsi                  GORONTALO    %
# 597 2021-01-01  Pertumbuhan Ekonomi Provinsi        NUSA TENGGARA BARAT    %
# 598 2021-01-01  Pertumbuhan Ekonomi Provinsi                PAPUA BARAT    %
# 599 2021-01-01  Pertumbuhan Ekonomi Provinsi                       BALI    %
#
#          Nilai
# 565  16.790001
# 566  15.160000
# 567  11.700000
# 568   5.580000
# 569   5.050000
# 570   4.800000
# 571   4.640000
# 572   4.490000
# 573   4.160000
# 574   4.100000
# 575   3.980000
# 576   3.740000
# 577   3.700000
# 578   3.690000
# 579   3.590000
# 580   3.580000
# 581   3.560000
# 582   3.560000
# 583   3.480000
# 584   3.430000
# 585   3.360000
# 586   3.330000
# 587   3.290000
# 588   3.270000
# 589   3.050000
# 590   2.790000
# 591   2.770000
# 592   2.610000
# 593   2.570000
# 594   2.550000
# 595   2.520000
# 596   2.410000
# 597   2.300000
# 598  -0.510000
# 599  -2.460000

# %%
# Menggunakan sort_values dengan beberapa kolom
data.sort_values(by=["Tahun", "Nilai"], ascending = False)
# Out:
#          Tahun                                Indikator  \
# 708 2022-01-01      Persentase Penduduk Miskin Provinsi
# 743 2022-01-01             Pertumbuhan Ekonomi Provinsi
# 709 2022-01-01      Persentase Penduduk Miskin Provinsi
# 710 2022-01-01      Persentase Penduduk Miskin Provinsi
# 711 2022-01-01      Persentase Penduduk Miskin Provinsi
# ..         ...                                      ...
# 140 2018-01-01  Indeks Keparahan Kemiskinan P2 Provinsi
# 141 2018-01-01  Indeks Keparahan Kemiskinan P2 Provinsi
# 142 2018-01-01  Indeks Keparahan Kemiskinan P2 Provinsi
# 179 2018-01-01                      Gini Ratio Provinsi
# 71  2018-01-01             Pertumbuhan Ekonomi Provinsi
#
#                       Provinsi    Unit      Nilai
# 708                      PAPUA       %  26.559999
# 743               MALUKU UTARA       %  22.940001
# 709                PAPUA BARAT       %  21.330000
# 710        NUSA TENGGARA TIMUR       %  20.049999
# 711                     MALUKU       %  15.970000
# ..                         ...     ...        ...
# 140  KEPULAUAN BANGKA BELITUNG  indeks   0.140000
# 141                DKI JAKARTA  indeks   0.110000
# 142             KEPULAUAN RIAU  indeks   0.110000
# 179               MALUKU UTARA       %   0.000000
# 71         NUSA TENGGARA BARAT       %  -4.500000
#
# [875 rows x 5 columns]

# %% [markdown]
# ###Grouping

# %% [markdown]
# Di Pandas, pengelompokan data dapat dilakukan berdasarkan kolom tertentu menggunakan `groupby()`. Setelah melakukan grouping, kita akan mendapatkan `DataFrameGroupBy object` yang dapat digunakan untuk melakukan berbagai analisis dan perhitungan statistik.

# %%
data_tahun_indikator = data.groupby(["Tahun","Indikator"])
# Menghitung rata-rata pada masing-masing kategori
data_tahun_indikator.Nilai.mean()
# Out:
# Tahun       Indikator
# 2018-01-01  Gini Ratio Provinsi                         0.350057
#             Indeks Kedalaman Kemiskinan P1 Provinsi     1.940486
#             Indeks Keparahan Kemiskinan P2 Provinsi     0.528857
#             Persentase Penduduk Miskin Provinsi        10.877714
#             Pertumbuhan Ekonomi Provinsi                5.645143
# 2019-01-01  Gini Ratio Provinsi                         0.342220
#             Indeks Kedalaman Kemiskinan P1 Provinsi     1.828200
#             Indeks Keparahan Kemiskinan P2 Provinsi     0.477714
#             Persentase Penduduk Miskin Provinsi        10.405714
#             Pertumbuhan Ekonomi Provinsi                4.692571
# 2020-01-01  Gini Ratio Provinsi                         0.333603
#             Indeks Kedalaman Kemiskinan P1 Provinsi     1.864200
#             Indeks Keparahan Kemiskinan P2 Provinsi     0.494571
#             Persentase Penduduk Miskin Provinsi        10.490571
#             Pertumbuhan Ekonomi Provinsi               -1.262000
# 2021-01-01  Gini Ratio Provinsi                         0.243243
#             Indeks Kedalaman Kemiskinan P1 Provinsi     1.885686
#             Indeks Keparahan Kemiskinan P2 Provinsi     0.494000
#             Persentase Penduduk Miskin Provinsi        10.810286
#             Pertumbuhan Ekonomi Provinsi                4.189429
# 2022-01-01  Gini Ratio Provinsi                         0.345086
#             Indeks Kedalaman Kemiskinan P1 Provinsi     1.796286
#             Indeks Keparahan Kemiskinan P2 Provinsi     0.472857
#             Persentase Penduduk Miskin Provinsi        10.301714
#             Pertumbuhan Ekonomi Provinsi                5.742857
# Name: Nilai, dtype: float64

# %%
#Menghitung nilai maksimum/minimum dengan max() atau min()
data_tahun_indikator.Nilai.max()
# Out:
# Tahun       Indikator
# 2018-01-01  Gini Ratio Provinsi                         0.441000
#             Indeks Kedalaman Kemiskinan P1 Provinsi     6.730000
#             Indeks Keparahan Kemiskinan P2 Provinsi     2.380000
#             Persentase Penduduk Miskin Provinsi        27.740000
#             Pertumbuhan Ekonomi Provinsi               20.600000
# 2019-01-01  Gini Ratio Provinsi                         0.423000
#             Indeks Kedalaman Kemiskinan P1 Provinsi     7.170000
#             Indeks Keparahan Kemiskinan P2 Provinsi     2.600000
#             Persentase Penduduk Miskin Provinsi        27.530001
#             Pertumbuhan Ekonomi Provinsi                8.830000
# 2020-01-01  Gini Ratio Provinsi                         0.434000
#             Indeks Kedalaman Kemiskinan P1 Provinsi     6.160000
#             Indeks Keparahan Kemiskinan P2 Provinsi     2.080000
#             Persentase Penduduk Miskin Provinsi        26.639999
#             Pertumbuhan Ekonomi Provinsi                5.390000
# 2021-01-01  Gini Ratio Provinsi                         0.441000
#             Indeks Kedalaman Kemiskinan P1 Provinsi     5.600000
#             Indeks Keparahan Kemiskinan P2 Provinsi     1.960000
#             Persentase Penduduk Miskin Provinsi        26.860001
#             Pertumbuhan Ekonomi Provinsi               16.790001
# 2022-01-01  Gini Ratio Provinsi                         0.439000
#             Indeks Kedalaman Kemiskinan P1 Provinsi     6.160000
#             Indeks Keparahan Kemiskinan P2 Provinsi     2.100000
#             Persentase Penduduk Miskin Provinsi        26.559999
#             Pertumbuhan Ekonomi Provinsi               22.940001
# Name: Nilai, dtype: float64

# %% [markdown]
# Melakukan banyak perhitungan sekaligus menggunakan `agg()`

# %%
#Menggunakan agg untuk melihat nilai min, max, dan rata-rata
data_tahun_indikator.Nilai.agg(["min", "max", "mean"])
# Out:
#                                                        min        max  \
# Tahun      Indikator
# 2018-01-01 Gini Ratio Provinsi                       0.000   0.441000
#            Indeks Kedalaman Kemiskinan P1 Provinsi   0.500   6.730000
#            Indeks Keparahan Kemiskinan P2 Provinsi   0.110   2.380000
#            Persentase Penduduk Miskin Provinsi       3.570  27.740000
#            Pertumbuhan Ekonomi Provinsi             -4.500  20.600000
# 2019-01-01 Gini Ratio Provinsi                       0.000   0.423000
#            Indeks Kedalaman Kemiskinan P1 Provinsi   0.400   7.170000
#            Indeks Keparahan Kemiskinan P2 Provinsi   0.070   2.600000
#            Persentase Penduduk Miskin Provinsi       3.470  27.530001
#            Pertumbuhan Ekonomi Provinsi            -15.740   8.830000
# 2020-01-01 Gini Ratio Provinsi                       0.000   0.434000
#            Indeks Kedalaman Kemiskinan P1 Provinsi   0.520   6.160000
#            Indeks Keparahan Kemiskinan P2 Provinsi   0.100   2.080000
#            Persentase Penduduk Miskin Provinsi       3.780  26.639999
#            Pertumbuhan Ekonomi Provinsi             -9.340   5.390000
# 2021-01-01 Gini Ratio Provinsi                       0.000   0.441000
#            Indeks Kedalaman Kemiskinan P1 Provinsi   0.600   5.600000
#            Indeks Keparahan Kemiskinan P2 Provinsi   0.110   1.960000
#            Persentase Penduduk Miskin Provinsi       4.530  26.860001
#            Pertumbuhan Ekonomi Provinsi             -2.460  16.790001
# 2022-01-01 Gini Ratio Provinsi                       0.236   0.439000
#            Indeks Kedalaman Kemiskinan P1 Provinsi   0.600   6.160000
#            Indeks Keparahan Kemiskinan P2 Provinsi   0.130   2.100000
#            Persentase Penduduk Miskin Provinsi       4.450  26.559999
#            Pertumbuhan Ekonomi Provinsi              2.010  22.940001
#
#                                                          mean
# Tahun      Indikator
# 2018-01-01 Gini Ratio Provinsi                       0.350057
#            Indeks Kedalaman Kemiskinan P1 Provinsi   1.940486
#            Indeks Keparahan Kemiskinan P2 Provinsi   0.528857
#            Persentase Penduduk Miskin Provinsi      10.877714
#            Pertumbuhan Ekonomi Provinsi              5.645143
# 2019-01-01 Gini Ratio Provinsi                       0.342220
#            Indeks Kedalaman Kemiskinan P1 Provinsi   1.828200
#            Indeks Keparahan Kemiskinan P2 Provinsi   0.477714
#            Persentase Penduduk Miskin Provinsi      10.405714
#            Pertumbuhan Ekonomi Provinsi              4.692571
# 2020-01-01 Gini Ratio Provinsi                       0.333603
#            Indeks Kedalaman Kemiskinan P1 Provinsi   1.864200
#            Indeks Keparahan Kemiskinan P2 Provinsi   0.494571
#            Persentase Penduduk Miskin Provinsi      10.490571
#            Pertumbuhan Ekonomi Provinsi             -1.262000
# 2021-01-01 Gini Ratio Provinsi                       0.243243
#            Indeks Kedalaman Kemiskinan P1 Provinsi   1.885686
#            Indeks Keparahan Kemiskinan P2 Provinsi   0.494000
#            Persentase Penduduk Miskin Provinsi      10.810286
#            Pertumbuhan Ekonomi Provinsi              4.189429
# 2022-01-01 Gini Ratio Provinsi                       0.345086
#            Indeks Kedalaman Kemiskinan P1 Provinsi   1.796286
#            Indeks Keparahan Kemiskinan P2 Provinsi   0.472857
#            Persentase Penduduk Miskin Provinsi      10.301714
#            Pertumbuhan Ekonomi Provinsi              5.742857

# %% [markdown]
# `describe()` untuk menunjukkan rangkuman statistik seperti rata-rata, median, dll pada kolom

# %%
#Menggunakan describe
data_tahun_indikator.describe()
# Out:
#                                                    Nilai                       \
#                                                    count       mean       std
# Tahun      Indikator
# 2018-01-01 Gini Ratio Provinsi                      35.0   0.350057  0.070087
#            Indeks Kedalaman Kemiskinan P1 Provinsi  35.0   1.940486  1.433389
#            Indeks Keparahan Kemiskinan P2 Provinsi  35.0   0.528857  0.508595
#            Persentase Penduduk Miskin Provinsi      35.0  10.877714  5.695497
#            Pertumbuhan Ekonomi Provinsi             35.0   5.645143  3.284288
# 2019-01-01 Gini Ratio Provinsi                      35.0   0.342220  0.069486
#            Indeks Kedalaman Kemiskinan P1 Provinsi  35.0   1.828200  1.422615
#            Indeks Keparahan Kemiskinan P2 Provinsi  35.0   0.477714  0.511089
#            Persentase Penduduk Miskin Provinsi      35.0  10.405714  5.587855
#            Pertumbuhan Ekonomi Provinsi             35.0   4.692571  3.748642
# 2020-01-01 Gini Ratio Provinsi                      35.0   0.333603  0.089501
#            Indeks Kedalaman Kemiskinan P1 Provinsi  35.0   1.864200  1.317897
#            Indeks Keparahan Kemiskinan P2 Provinsi  35.0   0.494571  0.457084
#            Persentase Penduduk Miskin Provinsi      35.0  10.490571  5.447510
#            Pertumbuhan Ekonomi Provinsi             35.0  -1.262000  2.384072
# 2021-01-01 Gini Ratio Provinsi                      35.0   0.243243  0.170271
#            Indeks Kedalaman Kemiskinan P1 Provinsi  35.0   1.885686  1.226755
#            Indeks Keparahan Kemiskinan P2 Provinsi  35.0   0.494000  0.408406
#            Persentase Penduduk Miskin Provinsi      35.0  10.810286  5.404172
#            Pertumbuhan Ekonomi Provinsi             35.0   4.189429  3.573612
# 2022-01-01 Gini Ratio Provinsi                      35.0   0.345086  0.046217
#            Indeks Kedalaman Kemiskinan P1 Provinsi  35.0   1.796286  1.203595
#            Indeks Keparahan Kemiskinan P2 Provinsi  35.0   0.472857  0.407652
#            Persentase Penduduk Miskin Provinsi      35.0  10.301714  5.182014
#            Pertumbuhan Ekonomi Provinsi             35.0   5.742857  3.649424
#
#                                                                            \
#                                                        min     25%    50%
# Tahun      Indikator
# 2018-01-01 Gini Ratio Provinsi                       0.000  0.3325  0.355
#            Indeks Kedalaman Kemiskinan P1 Provinsi   0.500  0.9650  1.560
#            Indeks Keparahan Kemiskinan P2 Provinsi   0.110  0.2250  0.410
#            Persentase Penduduk Miskin Provinsi       3.570  6.6450  9.820
#            Pertumbuhan Ekonomi Provinsi             -4.500  5.0750  5.470
# 2019-01-01 Gini Ratio Provinsi                       0.000  0.3295  0.341
#            Indeks Kedalaman Kemiskinan P1 Provinsi   0.400  0.9250  1.440
#            Indeks Keparahan Kemiskinan P2 Provinsi   0.070  0.2100  0.310
#            Persentase Penduduk Miskin Provinsi       3.470  6.5250  8.830
#            Pertumbuhan Ekonomi Provinsi            -15.740  4.7650  5.260
# 2020-01-01 Gini Ratio Provinsi                       0.000  0.3230  0.340
#            Indeks Kedalaman Kemiskinan P1 Provinsi   0.520  1.0050  1.530
#            Indeks Keparahan Kemiskinan P2 Provinsi   0.100  0.2300  0.390
#            Persentase Penduduk Miskin Provinsi       3.780  6.5300  8.750
#            Pertumbuhan Ekonomi Provinsi             -9.340 -2.3350 -1.130
# 2021-01-01 Gini Ratio Provinsi                       0.000  0.0000  0.326
#            Indeks Kedalaman Kemiskinan P1 Provinsi   0.600  1.0350  1.520
#            Indeks Keparahan Kemiskinan P2 Provinsi   0.110  0.2350  0.380
#            Persentase Penduduk Miskin Provinsi       4.530  6.7600  9.010
#            Pertumbuhan Ekonomi Provinsi             -2.460  2.7800  3.560
# 2022-01-01 Gini Ratio Provinsi                       0.236  0.3140  0.339
#            Indeks Kedalaman Kemiskinan P1 Provinsi   0.600  1.0100  1.360
#            Indeks Keparahan Kemiskinan P2 Provinsi   0.130  0.2450  0.340
#            Persentase Penduduk Miskin Provinsi       4.450  6.2750  8.630
#            Pertumbuhan Ekonomi Provinsi              2.010  4.4400  5.110
#
#
#                                                         75%        max
# Tahun      Indikator
# 2018-01-01 Gini Ratio Provinsi                       0.3870   0.441000
#            Indeks Kedalaman Kemiskinan P1 Provinsi   2.4600   6.730000
#            Indeks Keparahan Kemiskinan P2 Provinsi   0.6050   2.380000
#            Persentase Penduduk Miskin Provinsi      13.5750  27.740000
#            Pertumbuhan Ekonomi Provinsi              6.2250  20.600000
# 2019-01-01 Gini Ratio Provinsi                       0.3805   0.423000
#            Indeks Kedalaman Kemiskinan P1 Provinsi   2.2785   7.170000
#            Indeks Keparahan Kemiskinan P2 Provinsi   0.5450   2.600000
#            Persentase Penduduk Miskin Provinsi      13.0950  27.530001
#            Pertumbuhan Ekonomi Provinsi              5.7550   8.830000
# 2020-01-01 Gini Ratio Provinsi                       0.3780   0.434000
#            Indeks Kedalaman Kemiskinan P1 Provinsi   2.2400   6.160000
#            Indeks Keparahan Kemiskinan P2 Provinsi   0.5550   2.080000
#            Persentase Penduduk Miskin Provinsi      12.7900  26.639999
#            Pertumbuhan Ekonomi Provinsi             -0.6350   5.390000
# 2021-01-01 Gini Ratio Provinsi                       0.3710   0.441000
#            Indeks Kedalaman Kemiskinan P1 Provinsi   2.2495   5.600000
#            Indeks Keparahan Kemiskinan P2 Provinsi   0.5900   1.960000
#            Persentase Penduduk Miskin Provinsi      12.9200  26.860001
#            Pertumbuhan Ekonomi Provinsi              4.1300  16.790001
# 2022-01-01 Gini Ratio Provinsi                       0.3735   0.439000
#            Indeks Kedalaman Kemiskinan P1 Provinsi   2.3100   6.160000
#            Indeks Keparahan Kemiskinan P2 Provinsi   0.5800   2.100000
#            Persentase Penduduk Miskin Provinsi      12.3100  26.559999
#            Pertumbuhan Ekonomi Provinsi              5.3400  22.940001

# %% [markdown]
# #**Pivot Data**
#
# Pivot merupakan sebuah yang disediakan oleh Pandas untuk melakukan reshaping data dengan mengubah baris menjadi kolom. Pivoting data dapat dilakukan dengan menggunakan `data.pivot(index, columns, values)`, di mana:
#
# 1. index: Label untuk membentuk indeks pada dataframe baru.
# 2. columns: Label untuk membentuk kolom pada dataframe baru.
# 3. values: Nilai yang akan diisi pada dataframe yang baru.
#
# Dengan menggunakan pivot, kita dapat mengatur ulang struktur data sehingga memudahkan analisis sesuai dengan kebutuhan.
#
#
# Berikut merupakan contoh penggunaan pivot dimana kita ingin melihat berbagai maca nilai indikator di provinsi Jawa Timur dari tahun 2018 hingga 2022.

# %%
#contoh penggunaan pivot
data_jatim = data[data.Provinsi == "JAWA TIMUR"]
data_jatim_pivot = data_jatim.pivot(index='Tahun', columns='Indikator', values='Nilai')
data_jatim_pivot
# Out:
# Indikator   Gini Ratio Provinsi  Indeks Kedalaman Kemiskinan P1 Provinsi  \
# Tahun
# 2018-01-01                0.379                                     1.94
# 2019-01-01                0.370                                     1.80
# 2020-01-01                0.366                                     1.82
# 2021-01-01                0.374                                     1.84
# 2022-01-01                0.371                                     0.77
#
# Indikator   Indeks Keparahan Kemiskinan P2 Provinsi  \
# Tahun
# 2018-01-01                                     0.50
# 2019-01-01                                     0.45
# 2020-01-01                                     0.43
# 2021-01-01                                     0.43
# 2022-01-01                                     0.38
#
# Indikator   Persentase Penduduk Miskin Provinsi  Pertumbuhan Ekonomi Provinsi
# Tahun
# 2018-01-01                                10.98                          5.47
# 2019-01-01                                10.37                          5.53
# 2020-01-01                                11.09                         -2.33
# 2021-01-01                                11.40                          3.56
# 2022-01-01                                10.38                          5.34

# %% [markdown]
# ##**Soal 1**
#
# Buatlah pivot table dari `data` untuk menampilkan rata-rata nilai selama 5 tahun berdasarkan provinsi sebagai index dan indikator sebagai kolom. Untuk mencari rata-rata, gunakan parameter `aggfunc = 'mean'`

# %%
#jawab soal 1

# %% [markdown]
# #**Visualisasi Data**
#
# Untuk membuat chart pada matplotlib, yang digunakan adalah `plt.nama_plot()`.
#
# Selain menggunakan matplotlib, visualisasi data dapat dilakukan di Pandas yang didukung oleh library Matplotlib
#
# Dengan `plot`, berbagai jenis visualisasi data dapat dihasilkan melalui argumen `kind`.
#
# Contoh chart yang bisa dihasilkan oleh matplolib dan pandas
# - "bar" untuk bar chart
# - "pie" untuk pie chart
# - "hist" untuk histogram
# - "boxplot" pada matplotlib dan "box" pada pandas untuk box plot
# - "scatter" untuk scatter plot

# %% [markdown]
# ##**Bar chart matplotlib dan pandas**
#
# **Membuat bar chart pertumbuhan ekonomi pada setiap provinsi di tahun 2018**
#
# Untuk membuat chart tersebut, pertama kita filter terlebih dahulu sesuai data yang dibutuhkan, yaitu data tahun 2018 dengan indikator persentase penduduk miskin provinsi

# %%
data_2018_penduduk_miskin = data[(data.Tahun.dt.year == 2018) & (data.Indikator == 'Persentase Penduduk Miskin Provinsi')]
data_2018_penduduk_miskin

# %% [markdown]
# Setelah mendapat data yang dibutuhkan, kita akan membuat bar chart dengan matplotlib atau pandas

# %%
#bar chart dengan matplotlib
plt.figure(figsize=(15,6))
plt.bar(data_2018_penduduk_miskin.Provinsi, data_2018_penduduk_miskin.Nilai)
plt.xticks(rotation=90)
plt.title('Persentase Penduduk Miskin per Provinsi (Tahun 2018)')
plt.xlabel('Provinsi')
plt.ylabel('Persentase Penduduk Miskin (%)')
plt.show()

# %%
#bar chart dengan pandas
data_2018_penduduk_miskin.plot(kind='bar',
                          x='Provinsi',
                          y='Nilai',
                          figsize=(15, 6),
                          legend=False,
                          title = 'Persentase Penduduk Miskin per Provinsi (Tahun 2018)',
                          xlabel = 'Provinsi',
                          ylabel = 'Persentase Penduduk Miskin (%)')
plt.show()

# %% [markdown]
# ### **Soal 2**
#
# **Buatlah bar chart untuk menampilkan rata-rata Gini Ratio dari tahun 2018 hingga 2022**

# %%
#Jawab soal 2

# %% [markdown]
# ##**Line chart matplotlib dan pandas**
#
# **Membuat line chart persentase penduduk miskin pada provinsi Jawa Timur tahun 2018-2022**
#
# Untuk membuat chart tersebut, pertama kita filter terlebih dahulu sesuai data yang dibutuhkan, yaitu data provinsi Jawa Timur dengan indikator persentase penduduk miskin provinsi

# %%
data_miskin_jatim = data[(data.Provinsi == 'JAWA TIMUR') & (data.Indikator == 'Persentase Penduduk Miskin Provinsi')]
data_miskin_jatim

# %% [markdown]
# Setelah mendapat data yang dibutuhkan, kita akan membuat line chart dengan matplotlib atau pandas

# %%
#line chart dengan matplotlib
plt.figure(figsize=(15,6))
plt.plot(data_miskin_jatim.Tahun.dt.year, data_miskin_jatim.Nilai)
plt.title('Persentase Penduduk Miskin Jawa Timur Tahun 2018-2022')
plt.xlabel('Tahun')
plt.ylabel('Persentase Penduduk Miskin (%)')
plt.xticks(data_miskin_jatim.Tahun.dt.year.astype(int)) #agar x axisnya berupa integer sehingga tidak ada komanya
plt.show()

# %%
#line chart dengan pandas
data_miskin_jatim.plot( x='Tahun',
                        y='Nilai',
                        figsize=(15, 6),
                        legend=False,
                        title = 'Persentase Penduduk Miskin Jawa Timur Tahun 2018-2022',
                        xlabel = 'Tahun',
                        ylabel = 'Persentase Penduduk Miskin (%)')
plt.show()

# %% [markdown]
# ### **Soal 3**
#
# **Buatlah line chart mengenai pertumbuhan ekonomi Indonesia dari tahun 2018 hingga 2022**

# %%
#jawab soal 3

# %% [markdown]
# ##**Scatter plot matplotlib dan pandas**
#
# **Analisis korelasi antara Indeks Kedalaman Kemiskinan (P1) dengan Indeks Keparahan Kemiskinan (P2) di setiap provinsi pada tahun 2018.**
#
# Untuk membuat chart tersebut, pertama kita filter terlebih dahulu sesuai data yang dibutuhkan, yang pertama, yaitu data tahun 2018 dengan indikator indeks kedalaman kemiskinan p1 provinsi

# %%
data_2018_p1 = data[(data.Tahun.dt.year == 2018) & (data.Indikator == 'Indeks Kedalaman Kemiskinan P1 Provinsi')]
data_2018_p1

# %% [markdown]
# Setelah itu, kita filter terlebih dahulu data kedua yang dibutuhkan, yaitu data tahun 2018 dengan indikator indeks kedalaman kemiskinan p2 provinsi

# %%
data_2018_p2 = data[(data.Tahun.dt.year == 2018) & (data.Indikator == 'Indeks Keparahan Kemiskinan P2 Provinsi')]
data_2018_p2

# %% [markdown]
# Setelah melakukan filtering, kita akan mendapatkan 2 data frame baru. Untuk mempermudah pembuatan chart, kita bisa menggabungkan kedua data frame tersebut menggunakan `merge(data, on='column')`. Dimana data merupakan nama data frame yang akan digabungkan dan parameter on diisi dengan nama kolom yang akan digabungkan

# %%
data_2018_merged = data_2018_p1.merge(data_2018_p2, on='Provinsi')
data_2018_merged

# %% [markdown]
# Setelah mendapat data yang dibutuhkan, kita akan membuat scatter plot dengan matplotlib atau pandas

# %%
#scatter plot dengan matplotlib
plt.figure(figsize=(15,6))
plt.scatter(data_2018_merged.Nilai_x, data_2018_merged.Nilai_y)
plt.title('Korelasi Antara Indeks Kedalaman Kemiskinan (P1) dengan Indeks Keparahan Kemiskinan (P2) Di Setiap Provinsi Pada Tahun 2018')
plt.xlabel('Indeks Kedalaman Kemiskinan P1 Provinsi (%)')
plt.ylabel('Indeks Keparahan Kemiskinan P2 Provinsi (indeks)')
plt.show()

# %%
#scatter plot dengan pandas
data_2018_merged.plot(kind='scatter',
                      x='Nilai_x',
                      y='Nilai_y',
                      figsize=(15, 6),
                      legend=False,
                      title = 'Korelasi Antara Indeks Kedalaman Kemiskinan (P1) dengan Indeks Keparahan Kemiskinan (P2) Di Setiap Provinsi Pada Tahun 2018',
                      xlabel = 'Indeks Kedalaman Kemiskinan P1 Provinsi (%)',
                      ylabel = 'Indeks Keparahan Kemiskinan P2 Provinsi (indeks)')
plt.show()

# %% [markdown]
# ### **Soal 4**
#
# **Buatlah scatter plot yang menunjukkan korelasi antara persentase penduduk miskin dengan pertumbuhan ekonomi pada tahun 2022**

# %%
#jawab soal 4

# %% [markdown]
# ##**Grouped bar chart**
#
# **Membuat grouped bar chart dengan indikator pertumbuhan ekonomi per provinsi dan persentase penduduk miskin di tahun 2018**
#
# Untuk membuat chart tersebut, pertama kita filter terlebih dahulu sesuai data yang dibutuhkan, yaitu data tahun 2018 dengan indikator pertumbuhan ekonomi provinsi

# %%
data_2018_pertum_ekonomi = data[(data.Tahun.dt.year == 2018) & (data.Indikator == 'Pertumbuhan Ekonomi Provinsi')]
data_2018_pertum_ekonomi.sort_values(by='Provinsi', inplace=True)
data_2018_pertum_ekonomi

# %%
#grouped bar chart dengan matplotlib
data_2018_penduduk_miskin.sort_values(by='Provinsi', inplace=True)

plt.figure(figsize=(20,6))
bar_width = 0.35
r1 = range(len(data_2018_penduduk_miskin))
r2 = [x + bar_width for x in r1]
plt.bar(r1, data_2018_penduduk_miskin.Nilai, color='b', width=bar_width, edgecolor='grey', label='Persentase Penduduk Miskin')
plt.bar(r2, data_2018_pertum_ekonomi.Nilai, color='g', width=bar_width, edgecolor='grey', label='Pertumbuhan Ekonomi')
plt.xticks([r + bar_width / 2 for r in range(len(data_2018_penduduk_miskin))], data_2018_penduduk_miskin.Provinsi, rotation=90)
plt.xlabel('Provinsi')
plt.ylabel('Nilai')
plt.title('Persentase Penduduk Miskin dan Pertumbuhan Ekonomi Berdasarkan Provinsi')
plt.legend()

plt.show()

# %% [markdown]
# ##**Line chart dan bar chart**
#
# Pada section ini, kita akan menggabungkan bar chart dan line chart dalam satu figure. Data yang digunakan adalah sheet `Persentase Kemiskinan` dari file excel `Data Kemiskinan 2018-2022.xlsx`. Sehingga kita perlu melakukan import sheet excel tersebut

# %%
kemiskinan_prov = pd.read_excel('Data Kemiskinan 2018-2022.xlsx', sheet_name='Persentase Kemiskinan')
kemiskinan_prov

# %% [markdown]
# Selanjutnya, data akan difilter menjadi 2 data frame baru yaitu data frame dengan unit % dan data frame dengan unit ribu jiwa

# %%
df_persen = kemiskinan_prov[kemiskinan_prov.Unit == '%']
df_persen

# %%
df_ribu_jiwa = kemiskinan_prov[kemiskinan_prov.Unit == 'ribu jiwa']
df_ribu_jiwa

# %% [markdown]
# Setelah itu, kita bisa membuat figure dengan gabungan line chart dan bar chart menggunakan kedua data di atas

# %%
fig, ax = plt.subplots(figsize=(15, 6))

line = ax.plot(df_ribu_jiwa.Tahun.dt.year, df_persen.Nilai, 'ro-', label='Persentase Penduduk Miskin (%)', linewidth=2)
ax.set_xlabel('Tahun')
ax.set_ylabel('Nilai')
ax.set_title('Jumlah Penduduk Miskin dan Persentase Kemiskinan')
ax.set_xticks(df_ribu_jiwa.Tahun.dt.year.astype(int))

ax2 = ax.twinx() #untuk membuat y-axis kedua buat bar chart
bars = ax2.bar(df_ribu_jiwa.Tahun.dt.year, df_ribu_jiwa.Nilai, alpha = 0.5, color='y', label='Jumlah Penduduk Miskin (ribu jiwa)', width = 0.6)


ax.legend(loc='upper left')
ax2.legend(loc='upper right')

ax2.bar_label(ax2.containers[0]) #memberi nilai pada bar chart

plt.show()

# %% [markdown]
# ### **Soal 5**
#
# Buatlah figure yang berisi gabungan line chart dan bar chart seperti di atas. Gunakan data dari sheet `Persentase Kemiskinan Jakarta` pada file excel `Data Kemiskinan 2018-2022.xlsx`. Sebelum membuat chart, lakukanlah data cleaning yang meliputi:
# 1. Menghilangkan baris yang memiliki missing value
# 2. Memperbaiki data dengan tipe data yang tidak sesuai
# 3. Menghilangkan data duplikat

# %%
#jawab soal 5

# %% [markdown]
# ##**Subplot**
#
# Pembuatan subplot dilakukan dengan `plt.subplots(jumlah_baris, jumlah_kolom, figsize=ukuran_figure)`. Dimana `fig` adalah objek gambar, dan `axs` adalah array dari subplot axes.

# %%
fig, axs = plt.subplots(2, 1, figsize=(15, 10))

axs[0].scatter(data_2018_merged.Nilai_x, data_2018_merged.Nilai_y)
axs[0].set_title('Korelasi Antara Indeks Kedalaman Kemiskinan (P1) dengan Indeks Keparahan Kemiskinan (P2) Di Setiap Provinsi Pada Tahun 2018')
axs[0].set_xlabel('Indeks Kedalaman Kemiskinan P1 Provinsi (%)')
axs[0].set_ylabel('Indeks Keparahan Kemiskinan P2 Provinsi (indeks)')

axs[1].bar(data_2018_penduduk_miskin.Provinsi, data_2018_penduduk_miskin.Nilai)
axs[1].tick_params(rotation=90)
axs[1].set_title('Persentase Penduduk Miskin per Provinsi (Tahun 2018)')
axs[1].set_xlabel('Provinsi')
axs[1].set_ylabel('Persentase Penduduk Miskin (%)')

plt.show()

# %% [markdown]
# Cara lainnya jika melakukakn plotting dengan pandas, yaitu dengan menambahkan parameter `ax=axs[baris_ke, kolom_ke]`. Karena subplot pada contoh di bawah hanya 1 dimensi maka menjadi `ax=axs[baris_ke]`

# %%
fig, axs = plt.subplots(2, 1, figsize=(15, 10))

data_2018_merged.plot(kind='scatter',
                      x='Nilai_x',
                      y='Nilai_y',
                      figsize=(15, 6),
                      legend=False,
                      title = 'Korelasi Antara Indeks Kedalaman Kemiskinan (P1) dengan Indeks Keparahan Kemiskinan (P2) Di Setiap Provinsi Pada Tahun 2018',
                      xlabel = 'Indeks Kedalaman Kemiskinan P1 Provinsi (%)',
                      ylabel = 'Indeks Keparahan Kemiskinan P2 Provinsi (indeks)',
                      ax=axs[0])

data_2018_penduduk_miskin.plot(kind='bar',
                          x='Provinsi',
                          y='Nilai',
                          figsize=(15, 6),
                          legend=False,
                          title = 'Persentase Penduduk Miskin per Provinsi (Tahun 2018)',
                          xlabel = 'Provinsi',
                          ylabel = 'Persentase Penduduk Miskin (%)',
                          ax=axs[1])

plt.show()

# %% [markdown]
# #**Tugas**

# %% [markdown]
# Buatlah 1 figure yang berisi 4 subplot dari data pada sheet `Indikator Kemiskinan` di file `Data Kemiskinan 2018-2022.xlsx`. Ketentuan 4 subplot tersebut adalah sebagai berikut.
# - Subplot pertama : **grouped bar chart** untuk menampilkan persentase `Akses Terhadap Layanan Kesehatan` dengan sub indikator `BPJS kesehatan, Tidak Punya, Perusahaan/Kantor, Asuransi Swasta, Jamkesda` pada tahun 2017-2022
# - Subplot kedua : **grouped bar chart** untuk menampilkan persentase `Persentase Pengeluaran Perkapita untuk Makanan Menurut Kabupaten/Kota dan Status Miskin Provinsi` dengan sub indikator `miskin, miskin dan tidak miskin, tidak miskin` pada tahun 2017-2022
# - Subplot ketiga : **line chart** mengenai `Kebijakan Publik` untuk menampilkan `Jumlah Bantuan Beras Provinsi` pada tahun 2017-2022
# - Subplot keempat : **line chart** mengenai `Pendidikan` untuk menampilkan `Rata-rata Lama Sekolah (Metode Baru) Provinsi` pada tahun 2017-2022
#
# Contoh hasil:
# ![download.png](https://drive.google.com/uc?export=view&id=1sKon210OW9zLMpR6M40-WtSaSTtaMvyV)

# %%
#jawab tugas
